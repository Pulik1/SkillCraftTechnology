# %% [markdown]
# <a href="https://colab.research.google.com/github/Pulik1/SkillCraftTechnology/blob/main/SCT_0437_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importing Required Libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()  # Upload the dataset manually
# Out:
#      <input type="file" id="files-f5c86f11-320d-4dc0-a635-b631cba8344b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f5c86f11-320d-4dc0-a635-b631cba8344b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Load the dataset
dataset_path = 'imdb_top_1000.csv'
movie_df = pd.read_csv(dataset_path)

# Display the first few rows
print(movie_df.head())
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
#Bar chart for genres.

# Split genres and count occurrences for avoiding clustering of data
genre_counts = df['Genre'].str.split(', ').explode().value_counts()

# Show only top 20 genres
top_genres = genre_counts.head(20)

# Plot bar chart
plt.figure(figsize=(10, 6))
top_genres.plot(kind='bar', color='skyblue')
plt.title('Top 20 Most Common Movie Genres')
plt.xlabel('Genre')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
#Bar chart for top directors



# Count movies by each director
director_counts = df['Director'].value_counts()

# Select the top 20 directors
top_directors = director_counts.head(20)

# Plot the bar chart
plt.figure(figsize=(16,9))
top_directors.plot(kind='bar', color='orange')
plt.title('Top 20 Directors with the Most Movies')
plt.xlabel('Number of Movies')
plt.ylabel('Director')
plt.xticks(rotation=45)
plt.show()

# %%
#Histograms for movie rating
plt.figure(figsize=(8, 6))
plt.hist(df['IMDB_Rating'], bins=20, color='purple', edgecolor='black')
plt.title('Distribution of IMDb Ratings')
plt.xlabel('IMDb Rating')
plt.ylabel('Frequency')
plt.show()
